# %% [markdown]
# # Inference for Faster-RCNN

# %% [markdown]
# # Setup

# %%
import cv2
from IPython.display import Image, clear_output  # to display images
from google.colab.patches import cv2_imshow

def detectAndDisplay(frame):
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_gray = cv2.equalizeHist(frame_gray)
    dets = cascade.detectMultiScale(frame_gray)
    for (x,y,w,h) in dets:
        frame = cv2.rectangle(frame, (x, y), (x+w, y+h), (255,0,255), 4 )
    cv2_imshow(frame)

cascade_name = 'path-to-cascade.xml-file'
cascade = cv2.CascadeClassifier()
cascade.load(cascade_name)


img = cv2.imread('path-to-image') # path to image for initial run
detectAndDisplay(cv2.resize(img, (1000, 750)))

# %%
def detect(path):
    path = os.path.join(directory, filename)
    img = cv2.imread(path)
    img = cv2.resize(img, (1000, 750))
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.equalizeHist(img_gray)

    dets = cascade.detectMultiScale(img_gray)

    return dets, img

# %% [markdown]
# # Inference on folder

# %%
import os

directory = 'path-to-inference-folder'

for filename in os.listdir(directory):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        
        path = os.path.join(directory, filename)
        
        dets, img = detect(path)

        for (x,y,w,h) in dets:
            cv2.rectangle(img, (x, y), (x+w, y+h), (255,0,255), 4 )

        cv2_imshow(img)
