# %% [markdown]
# # YOLOv3 training
#
# Training implemented in relation to https://models.roboflow.com/object-detection/yolo-v3-pytorch

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/ultralytics/yolov3
# !pip uninstall -y pyyaml
# !pip install pyyaml==5.3.1

# %% [markdown]
# # Dataset download
#
# For roboflow, export data in YOLOv5 format. This procedure saves preparation.

# %%
# !curl -L "https://app.roboflow.com/ds/psIrYULRXH?key=E0o7zOZBf4" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %% [markdown]
# # Training

# %%
# for additional parameters: train.py --help

# %cd /content/yolov3

# !python3 train.py --data /content/data.yaml --epochs 1000 --weights yolov3-tiny.pt --img 416 --batch 2 --device 0
